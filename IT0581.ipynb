# %% [markdown]
# <a href="https://colab.research.google.com/github/VenuGopalboggala/-CSA0489-OPERATING-SYSTEM-/blob/main/IT0581.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b9efa01b-4841-4d94-bc20-f2b8a9640e19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9efa01b-4841-4d94-bc20-f2b8a9640e19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
#  image_processing.py  'input (1).jpg'   input.jpg   sample_data

# %%
import cv2
from google.colab.patches import cv2_imshow

# Read image
image = cv2.imread("input.jpg")

if image is None:
    print("Error: Image not found!")
else:
    cv2_imshow(image)

    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    cv2_imshow(gray_image)

    cv2.imwrite("grayscale_output.jpg", gray_image)

    print("Grayscale image saved successfully!")
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# Grayscale image saved successfully!

# %%
from google.colab import files
files.download("grayscale_output.jpg")

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("input.jpg")

if image is None:
    print("Error: Image not found!")
else:
    cv2_imshow(image)

    blurred = cv2.GaussianBlur(image, (5,5), 0)

    cv2_imshow(blurred)

    cv2.imwrite("gaussian_blur_output.jpg", blurred)

    print("Blurred image saved successfully!")
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# Blurred image saved successfully!

# %%
import cv2
from google.colab.patches import cv2_imshow

# Read the uploaded image
image = cv2.imread("input.jpg")   # change name if your file is different

if image is None:
    print("Error: Image not found!")
else:
    # Show original image
    cv2_imshow(image)

    # Convert to grayscale (required for Canny)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Canny Edge Detection
    edges = cv2.Canny(gray, 100, 200)

    # Show edge detected image
    cv2_imshow(edges)

    # Save the output
    cv2.imwrite("canny_output.jpg", edges)

    print("Canny edge image saved successfully!")
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# Canny edge image saved successfully!

# %%
import cv2
from google.colab.patches import cv2_imshow

# Read image
image = cv2.imread("input.jpg")   # change if your filename is different

if image is None:
    print("Error: Image not found!")
else:
    # Show original image
    print("Original Image:")
    cv2_imshow(image)

    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Histogram Equalization
    equalized = cv2.equalizeHist(gray)

    # Show equalized image
    print("Histogram Equalized Image:")
    cv2_imshow(equalized)

    # Save the output image
    cv2.imwrite("histogram_equalized_output.jpg", equalized)

    print("Histogram equalized image saved successfully!")
# Out:
# Original Image:
# <PIL.Image.Image image mode=RGB size=275x183>
# Histogram Equalized Image:
# <PIL.Image.Image image mode=L size=275x183>
# Histogram equalized image saved successfully!

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

def analyze_histogram(image_path):

    # Read image
    image = cv2.imread(image_path)

    if image is None:
        print("Error: Image not found!")
        return

    print("Input Image:")
    cv2_imshow(image)

    # Split the image into Blue, Green, Red channels
    channels = cv2.split(image)

    colors = ('b', 'g', 'r')
    channel_names = ["Blue", "Green", "Red"]

    plt.figure()
    plt.title("Color Histogram Analysis")
    plt.xlabel("Intensity Levels")
    plt.ylabel("Number of Pixels")

    # Calculate histogram for each channel
    for channel, color, name in zip(channels, colors, channel_names):

        hist = cv2.calcHist([channel], [0], None, [256], [0,256])

        print(f"\n{name} Channel Analysis:")
        print("Minimum Intensity:", int(np.min(channel)))
        print("Maximum Intensity:", int(np.max(channel)))
        print("Mean Intensity:", float(np.mean(channel)))

        plt.plot(hist, color=color)

    plt.show()

# Call the function
analyze_histogram("input.jpg")
# Out:
# Input Image:
# <PIL.Image.Image image mode=RGB size=275x183>
# Blue Channel Analysis:
# Minimum Intensity: 0
# Maximum Intensity: 201
# Mean Intensity: 122.1183308494784
#
# Green Channel Analysis:
# Minimum Intensity: 0
# Maximum Intensity: 193
# Mean Intensity: 121.09714853452559
#
# Red Channel Analysis:
# Minimum Intensity: 0
# Maximum Intensity: 255
# Mean Intensity: 176.88288127173374
